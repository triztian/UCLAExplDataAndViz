# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_name = 'Sale_Counts_City.csv'
sale_counts_city = pd.read_csv(os.path.join(os.path.join(os.getcwd(), file_name)))

# %%
sale_counts_city
# Out:
#       RegionID      RegionName     StateName  SizeRank  2008-03  2008-04  \
# 0       6181.0        New York      New York         1      NaN      NaN
# 1      12447.0     Los Angeles    California         2   1469.0   1733.0
# 2      17426.0         Chicago      Illinois         3   3007.0   3105.0
# 3      39051.0         Houston         Texas         4      NaN      NaN
# 4      13271.0    Philadelphia  Pennsylvania         5   1622.0   1836.0
# ...        ...             ...           ...       ...      ...      ...
# 6414   11019.0          Cusick    Washington      6415      0.0      0.0
# 6415   57212.0    Forest Falls    California      6416      3.0      1.0
# 6416  760887.0  Berlin Borough    New Jersey      6417      2.0      4.0
# 6417  182023.0         Henrico      Virginia      6418    138.0    139.0
# 6418  114834.0   East Pasadena    California      6419      3.0      0.0
#
#       2008-05  2008-06  2008-07  2008-08  ...  2017-05  2017-06  2017-07  \
# ...

# %%
ts_columns = sale_counts_city.columns.str.match('\d{4}-\d{2}')
ca_sd_data = sale_counts_city.iloc[8]

# %%
ca_sd_data[ts_columns].plot()
